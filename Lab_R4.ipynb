# %% [markdown]
# # Laboratorio de regresión - 4

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     | Eugenio Hernández Aranda  |
# | **Fecha**      | 08/02/2026  |
# | **Expediente** | 756225  |

# %% [markdown]
# ## Modelos penalizados

# %% [markdown]
# Hasta ahora la función de costo que usamos para decidir qué tan bueno es nuestro modelo al momento de ajustar es:
#
# $$ \text{RSS} = \sum_{i=1}^n e_i^2 = \sum_{i=1}^n (y_i - \hat{y_i})^2 $$

# %% [markdown]
# Dado que los errores obtenidos son una combinación de sesgo y varianza, puede ser que se sesgue un parámetro para minimizar el error. Esto significa que el modelo puede decidir que la salida no sea una combinación de los factores, sino una fuerte predilección sobre uno de los factores solamente.

# %% [markdown]
# E.g. se quiere ajustar un modelo
#
# $$ \hat{z} = \hat{\beta_0} + \hat{\beta_1} x + \hat{\beta_2} y $$

# %% [markdown]
# Se ajusta el modelo y se decide que la mejor decisión es $\hat{\beta_1} = 10000$ y $\hat{\beta_2}=50$. Considera limitaciones de problemas reales:
# - Quizás los parámetros son ajustes de maquinaria que se deben realizar para conseguir el mejor producto posible, y que $10000$ sea imposible de asignar.
# - Quizás los datos actuales están sesgados y sólo hacen parecer que uno de los factores importa más que el otro.

# %% [markdown]
# Una de las formas en las que se puede mitigar este problema es penalizando a los parámetros del modelo, cambiando la función de costo:

# %% [markdown]
# $$ \text{RSS}_{L2} = \sum_{i=1}^n e_i^2  + \lambda \sum_{j=1}^p \hat{\beta_j}^2 $$

# %% [markdown]
# El *L2* significa que se está agregando una penalización de segundo orden. Lo que hace esta penalización es que los factores ahora sólo tendrán permitido crecer si hay una reducción al menos proporcional en el error (sacrificamos sesgo, pero reducimos la varianza).

# %% [markdown]
# Asimismo, existe la penalización *L1*

# %% [markdown]
# $$ \text{RSS}_{L1} = \sum_{i=1}^n e_i^2  + \lambda \sum_{j=1}^p |\hat{\beta_j}| $$

# %% [markdown]
# A las penalizaciones *L2* y *L1* se les conoce también como Ridge y Lasso, respectivamente.

# %% [markdown]
# Para realizar una regresión con penalización de Ridge o de Lasso usamos el objeto `Ridge(alpha=?)` o `Lasso(alpha=?)` en lugar de `LinearRegression()` de `sklearn`.

# %% [markdown]
# Utiliza el dataset de publicidad (Advertising.csv) y realiza 3 regresiones múltiples:
#
# $$ \text{sales} = \beta_0 + \beta_1 (\text{TV}) + \beta_2 (\text{radio}) + \beta_3 (\text{newspaper}) + \epsilon $$

# %% [markdown]
# 1. Sin penalización
# 2. Con penalización L2
# 3. Con penalización L1
#
# ¿Qué puedes observar al ajustar los valores de `alpha`?
#
# Compara los resultados de los coeficientes utilizando valores diferentes de $\alpha$ y los $R^2$ resultantes.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f7df4f4-5e7f-44de-ae93-70c5bc37e728" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f7df4f4-5e7f-44de-ae93-70c5bc37e728">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
lr = LinearRegression()
ridge = Ridge()
lasso = Lasso()

# %%
df = pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
X_1 = df['TV'].to_numpy().reshape(-1,1)

# %%
X_2 = df['radio'].to_numpy().reshape(-1,1)

# %%
X_3 = df['newspaper'].to_numpy().reshape(-1,1)

# %%
X= np.hstack((X_1, X_2, X_3))

# %%
y= df['sales'].to_numpy().reshape(-1,1)

# %%
lr.fit(X,y)
B= lr.coef_
B1= B[:,0]
B2 = B[:,1]
B3= B[:,2]
B0 = lr.intercept_
print(f'{B0} + {B1}TV + {B2}radio + {B3}newspaper')
lr.score(X,y)
# Out:
# [2.93888937] + [0.04576465]TV + [0.18853002]radio + [-0.00103749]newspaper
# 0.8972106381789521

# %% [markdown]
# # Con penalización L2

# %%
#Con penalización L2
ridge = Ridge(alpha=99999999999999999)
ridge.fit(X,y)
B= ridge.coef_
B1= B[0]
B2 = B[1]
B3= B[2]
B0 = ridge.intercept_
print(f'{B0} + {B1}TV + {B2}radio + {B3}newspaper')
R2 = ridge.score(X,y)
print(R2)
# Out:
# [14.0225] + 6.972764874897491e-13TV + 8.882501999985237e-14radio + 5.162336999978407e-14newspaper
# 1.833977414378296e-11

# %% [markdown]
# # Con penalización L1

# %%
lasso = Lasso(alpha=10)
lasso.fit(X,y)
B= lasso.coef_
B1= B[0]
B2 = B[1]
B3= B[2]
B0 = lasso.intercept_
print(f'{B0} + {B1}TV + {B2}radio + {B3}newspaper')
R2 = lasso.score(X,y)
print(R2)
# Out:
# [14.0225] + 0.0TV + 0.0radio + 0.0newspaper
# 0.0

# %% [markdown]
#   ## En Lasso, conforme alpha va aumentando de valor, las variables TV, radio y newspaper y su R2 se igualan a 0, en cambio cuando usamos Ridge, las variables TV, Radio y newspaper van tendiendo a 0 junto al R2 conforme alpha va aumentando de valor
